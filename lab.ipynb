# %% [markdown]
# # MongoDB vs Cassandra Lab

# %% [markdown]
# ## Part 1 - MongoDB

# %% [markdown]
# ### MongoDB Commands
# ```javascript
# use shop
#
# db.orders.insertMany([
#   {"order_id": "001", "customer": "Anna", "country": "Cambodia", "total": 120},
#   {"order_id": "002", "customer": "Ben", "country": "USA", "total": 75},
#   {"order_id": "003", "customer": "Chenda", "country": "Cambodia", "total": 200},
#   {"order_id": "004", "customer": "Dara", "country": "Thailand", "total": 95},
#   {"order_id": "005", "customer": "Emily", "country": "USA", "total": 150}
# ])
#
# db.orders.find()
# db.orders.find({country: "Cambodia"})
# db.orders.find({customer: "Anna"})

# %% [markdown]
# ### MongoDB Output
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Part 2 — Cassandra

# %% [markdown]
# ### Cassandra Commands
# ```sql
# CREATE KEYSPACE shop
# WITH replication = {'class': 'SimpleStrategy', 'replication_factor': 1};
#
# USE shop;
#
# CREATE TABLE orders (
#   country text,
#   order_id text,
#   customer text,
#   total int,
#   PRIMARY KEY (country, order_id)
# );
#
# INSERT INTO orders (country, order_id, customer, total)
# VALUES ('Cambodia', '001', 'Anna', 120);
#
# INSERT INTO orders (country, order_id, customer, total)
# VALUES ('USA', '002', 'Ben', 75);
#
# INSERT INTO orders (country, order_id, customer, total)
# VALUES ('Cambodia', '003', 'Chenda', 200);
#
# INSERT INTO orders (country, order_id, customer, total)
# VALUES ('Thailand', '004', 'Dara', 95);
#
# INSERT INTO orders (country, order_id, customer, total)
# VALUES ('USA', '005', 'Emily', 150);
#
# SELECT * FROM orders WHERE country = 'Cambodia';
# SELECT * FROM orders WHERE customer = 'Anna';

# %% [markdown]
# ### Cassandra Output
# ![image.png](attachment:image.png)
